# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Downloads/Smartphone_Usage_Productivity_Dataset.csv")

# %%
df
# Out:
#       User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0          U1   58    Male    Professional     Android                1.3
# 1          U2   25    Male    Professional     Android                1.2
# 2          U3   19    Male         Student         iOS                5.3
# 3          U4   35  Female  Business Owner         iOS                5.8
# 4          U5   33    Male      Freelancer     Android                7.9
# ...       ...  ...     ...             ...         ...                ...
# 49995  U49996   44    Male  Business Owner     Android                5.9
# 49996  U49997   42   Other  Business Owner     Android                2.9
# 49997  U49998   27  Female      Freelancer         iOS                1.4
# 49998  U49999   41  Female  Business Owner         iOS                8.9
# 49999  U50000   46   Other      Freelancer     Android                8.8
#
#        Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# ...

# %%
df.head()
# Out:
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# 4                 1.3                        4          5.7             3
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Occupation                   0
# Device_Type                  0
# Daily_Phone_Hours            0
# Social_Media_Hours           0
# Work_Productivity_Score      0
# Sleep_Hours                  0
# Stress_Level                 0
# App_Usage_Count              0
# Caffeine_Intake_Cups         0
# Weekend_Screen_Time_Hours    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    50000 non-null  object
#  1   Age                        50000 non-null  int64
#  2   Gender                     50000 non-null  object
#  3   Occupation                 50000 non-null  object
#  4   Device_Type                50000 non-null  object
#  5   Daily_Phone_Hours          50000 non-null  float64
#  6   Social_Media_Hours         50000 non-null  float64
#  7   Work_Productivity_Score    50000 non-null  int64
#  8   Sleep_Hours                50000 non-null  float64
#  9   Stress_Level               50000 non-null  int64
#  10  App_Usage_Count            50000 non-null  int64
#  11  Caffeine_Intake_Cups       50000 non-null  int64
#  12  Weekend_Screen_Time_Hours  50000 non-null  float64
# ...

# %%
df.dtypes
# Out:
# User_ID                       object
# Age                            int64
# Gender                        object
# Occupation                    object
# Device_Type                   object
# Daily_Phone_Hours            float64
# Social_Media_Hours           float64
# Work_Productivity_Score        int64
# Sleep_Hours                  float64
# Stress_Level                   int64
# App_Usage_Count                int64
# Caffeine_Intake_Cups           int64
# Weekend_Screen_Time_Hours    float64
# dtype: object

# %%
df.describe()
# Out:
#                 Age  Daily_Phone_Hours  Social_Media_Hours  \
# count  50000.000000       50000.000000        50000.000000
# mean      39.034960           6.509116            4.267250
# std       12.414877           3.170903            2.164743
# min       18.000000           1.000000            0.500000
# 25%       28.000000           3.800000            2.400000
# 50%       39.000000           6.500000            4.300000
# 75%       50.000000           9.200000            6.100000
# max       60.000000          12.000000            8.000000
#
#        Work_Productivity_Score   Sleep_Hours  Stress_Level  App_Usage_Count  \
# count             50000.000000  50000.000000  50000.000000      50000.00000
# mean                  5.503760      6.497744      5.504500         32.43898
# std                   2.874806      1.449551      2.871095         16.12151
# min                   1.000000      4.000000      1.000000          5.00000
# ...

# %%
df.shape
# Out:
# (50000, 13)

# %%
df['Weekend_Screen_Time_Hours'].mean()
# Out:
# 8.006844

# %%
plt.figure()
df['Weekend_Screen_Time_Hours'].hist()
plt.title("Screen Time distribution")
plt.xlabel("Screen Time")
plt.ylabel("Number of user")
plt.show()

# %%
df['Daily_Phone_Hours']=df['Daily_Phone_Hours'].astype(int)

# %%
df.dtypes
# Out:
# User_ID                       object
# Age                            int64
# Gender                        object
# Occupation                    object
# Device_Type                   object
# Daily_Phone_Hours              int64
# Social_Media_Hours           float64
# Work_Productivity_Score        int64
# Sleep_Hours                  float64
# Stress_Level                   int64
# App_Usage_Count                int64
# Caffeine_Intake_Cups           int64
# Weekend_Screen_Time_Hours    float64
# dtype: object

# %%
plt.figure()
df["Daily_Phone_Hours"].hist(bins=30)
plt.title("Screen Time Distribution")
plt.xlabel("Hours PEr Day")
plt.ylabel("Number Of Users")
plt.show()

# %%
# Correlation Between Screen Time & Productivity

df[["Daily_Phone_Hours", "Work_Productivity_Score"]].corr()
# Out:
#                          Daily_Phone_Hours  Work_Productivity_Score
# Daily_Phone_Hours                  1.00000                 -0.00228
# Work_Productivity_Score           -0.00228                  1.00000

# %%
sns.scatterplot(x="Daily_Phone_Hours",y="Work_Productivity_Score",data=df)
plt.title("Screen Time Vs Productivity")
plt.show()

# %%
# High Productivity Low Usage Users
df[(df["Work_Productivity_Score"]>70) & (df["Daily_Phone_Hours"]<4)]
# Out:
# Empty DataFrame
# Columns: [User_ID, Age, Gender, Occupation, Device_Type, Daily_Phone_Hours, Social_Media_Hours, Work_Productivity_Score, Sleep_Hours, Stress_Level, App_Usage_Count, Caffeine_Intake_Cups, Weekend_Screen_Time_Hours]
# Index: []

# %%
# High Usage Low Productivity Users
df[(df["Work_Productivity_Score"]<70) & (df["Daily_Phone_Hours"]>4)]
# Out:
#       User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 2          U3   19    Male         Student         iOS                  5
# 3          U4   35  Female  Business Owner         iOS                  5
# 4          U5   33    Male      Freelancer     Android                  7
# 5          U6   32  Female         Student     Android                 10
# 6          U7   26    Male         Student         iOS                  5
# ...       ...  ...     ...             ...         ...                ...
# 49991  U49992   42  Female  Business Owner     Android                 11
# 49992  U49993   34    Male    Professional         iOS                 10
# 49995  U49996   44    Male  Business Owner     Android                  5
# 49998  U49999   41  Female  Business Owner         iOS                  8
# 49999  U50000   46   Other      Freelancer     Android                  8
#
#        Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# ...

# %%
# Correlation Heatmap
# HeatMap
sns.heatmap(df.select_dtypes(include=["number"]).corr(),annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Sleep vs Productivity
sns.scatterplot(x="Sleep_Hours",y="Work_Productivity_Score",data=df)
plt.show()

# %%
# Screen Time vs Sleep
sns.scatterplot(x="Daily_Phone_Hours" , y="Sleep_Hours", data=df)
plt.show()
